# %% [markdown]
# # ARC4 Cipher Experiments

# %% [markdown]
# ## Decoding Messages

# %% [markdown]
# ### Step 1: Initialize state

# %%
def arc4_init(key: list[int]) -> list[int]:
    # State initialization.
    state = [0] * 256
    for i in range(256):
        state[i] = i
    
    # Key-Scheduling Algorithm (KSA).
    j = 0
    for i in range(256):
        j = (j + state[i] + KEY[i % len(KEY)]) % 256

        # Swap state[i] and state[j].
        tmp = state[i]
        state[i] = state[j]
        state[j] = tmp

    return state


KEY = [0x00, 0x03, 0x3C]  # 0x00033C Big-endian
state = arc4_init(KEY)
print("\n".join([hex(s)[2:].upper() for s in state]))
# Out:
# B4
# 4
# 2B
# E5
# 49
# A
# 90
# 9A
# E4
# 17
# F4
# 10
# 3A
# 36
# 13
# 77
# 11
# C4
# BC
# 38
# 4F
# 6D
# 98
# 6
# 6E
# 3D
# 2C
# AE
# CD
# 26
# 40
# A2
# C2
# DA
# 67
# 68
# 5D
# 3E
# 2
# 73
# 3
# AA
# 94
# 69
# 6A
# 97
# 6F
# 33
# 63
# 5B
# 8A
# 58
# D9
# 61
# F5
# 46
# 96
# 55
# 7D
# 53
# 5F
# AB
# 7
# 9C
# A7
# 72
# 31
# A9
# C6
# 3F
# F9
# 91
# F2
# F6
# 7C
# C7
# B3
# 1D
# 20
# 88
# A0
# BA
# C
# 85
# E1
# CF
# CB
# 51
# C0
# 2E
# EF
# 80
# 76
# B2
# D6
# 71
# 24
# AD
# 6B
# DB
# FF
# FE
# ED
# 84
# 4E
# 8C
# BB
# D3
# A5
# 2F
# BE
# C8
# E
# 8F
# D1
# A6
# 86
# E3
# 62
# B0
# 87
# EC
# B9
# 78
# 81
# E0
# 4D
# 5A
# 7A
# 79
# 14
# 29
# 56
# E8
# 4A
# 8E
# 18
# C5
# CA
# B7
# 25
# DE
# 99
# C3
# 2A
# 65
# 30
# 1A
# EA
# FB
# A1
# 89
# 35
# A4
# 9
# A3
# C1
# D8
# 2D
# B8
# 60
# 47
# 39
# BD
# 1F
# 5
# 5E
# 43
# B1
# DD
# E9
# 1C
# AF
# 9B
# FA
# 1
# F7
# 8
# 75
# B6
# 82
# CE
# 42
# E2
# CC
# 9E
# EB
# 27
# 22
# DF
# BF
# FC
# D
# D0
# 95
# 23
# D2
# A8
# 7E
# 74
# 4C
# D7
# 12
# 7F
# FD
# 83
# 1E
# 28
# 64
# 54
# 3C
# 21
# DC
# F3
# 93
# 59
# 8B
# 7B
# 0
# 48
# E7
# 6C
# D5
# C9
# 70
# 9F
# AC
# 41
# B
# F0
# 19
# B5
# 8D
# 16
# D4
# F1
# 92
# 9D
# 66
# 44
# 4B
# 15
# 45
# F8
# F
# 57
# 34
# 32
# 50
# 52
# EE
# 3B
# 5C
# 37
# E6
# 1B

# %% [markdown]
# ### Step 2: Generate pad and XOR with ciphertext

# %%
def arc4_decode(state: list[int], encoded_msg: bytes):
    # Generate bytestream to be XOR'ed with the cipher text.
    i = 0
    j = 0

    pad = [0] * len(encoded_msg)
    for k in range(len(encoded_msg)):
        i = (i + 1) % 256
        j = (j + state[i]) % 256

        # Swap state[i] and state[j].
        tmp = state[i]
        state[i] = state[j]
        state[j] = tmp

        pad[k] = state[(state[i] + state[j]) % 256]

    decoded_msg = [0] * len(encoded_msg)
    for k in range(len(encoded_msg)):
        decoded_msg[k] = pad[k] ^ encoded_msg[k]

    return bytes(decoded_msg)

# %% [markdown]
# Decoding example:

# %%
KEY = [0x1E, 0x46, 0x00]  # 0x1E4600 Big-endian
state = arc4_init(KEY)
encoded_msg = [
    0xA7,
    0xFD,
    0x08,
    0x01,
    0x84,
    0x45,
    0x68,
    0x85,
    0x82,
    0x5C,
    0x85,
    0x97,
    0x43,
    0x4D,
    0xE7,
    0x07,
    0x25,
    0x0F,
    0x9A,
    0xEC,
    0xC2,
    0x6A,
    0x4E,
    0xA7,
    0x49,
    0xE0,
    0xEB,
    0x71,
    0xBC,
    0xAC,
    0xC7,
    0xD7,
    0x57,
    0xE9,
    0xE2,
    0xB1,
    0x1B,
    0x09,
    0x52,
    0x33,
    0x92,
    0xC1,
    0xB7,
    0xE8,
    0x4C,
    0xA1,
    0xD8,
    0x57,
    0x2F,
    0xFA,
    0xB8,
    0x72,
    0xB9,
    0x3A,
    0xFC,
    0x01,
    0xC3,
    0xE5,
    0x18,
    0x32,
    0xDF,
    0xBB,
    0x06,
    0x32,
    0x2E,
    0x4A,
    0x01,
    0x63,
    0x10,
    0x10,
    0x16,
    0xB5,
    0xD8,
]
decoded_msg = arc4_decode(state, encoded_msg)
print(decoded_msg)
# Out:
# b'It was a bright cold day in April, and the clocks were striking thirteen.'
